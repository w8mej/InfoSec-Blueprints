# %% [markdown]
# # UNCLASSIFIED / NON CLASSIFIÉ//TLP:WHITE# U/OO/712832-02 | QQ-09-1998
#  Please note that the original, detailed content has been removed or adjusted for public consumption. Most data has been redacted and replaced with generic, non-actionable insights. This modification ensures compliance with privacy considerations, non-disclosure agreements, and intellectual property rights that govern the dissemination of sensitive information. The priority is to respect these boundaries while still offering valuable, thought-provoking perspectives.

# %% [markdown]
# ![Build Status](https://img.shields.io/badge/Build-Passing-brightgreen?style=flat-square&logo=cyberpunk)         ![Documentation](https://img.shields.io/badge/Documentation-Complete-blue?style=flat-square&logo=cyberpunk)        ![Response Efficiency](https://img.shields.io/badge/Response%20Efficiency-98%25-green?style=flat-square&logo=cyberpunk)        ![Last Updated](https://img.shields.io/badge/Last%20Updated-Oct%202023-purple?style=flat-square&logo=cyberpunk)        ![Incidents Resolved](https://img.shields.io/badge/Incidents%20Resolved-150-red?style=flat-square&logo=cyberpunk)        ![Community Engagement](https://img.shields.io/badge/Community-Active-orange?style=flat-square&logo=cyberpunk)        ![Code Integration](https://img.shields.io/badge/Code%20Integration-High-teal?style=flat-square&logo=cyberpunk)        ![AI Analysis](https://img.shields.io/badge/AI%20Analysis-Advanced-blueviolet?style=flat-square&logo=cyberpunk)        ![Threat Detection](https://img.shields.io/badge/Threat%20Detection-Optimal-red?style=flat-square&logo=cyberpunk)        ![Cybersecurity Hardening](https://img.shields.io/badge/Security-Hardened-silver?style=flat-square&logo=cyberpunk)        ![Network Uptime](https://img.shields.io/badge/Uptime-99.9%25-brightgreen?style=flat-square&logo=cyberpunk)        ![Data Privacy](https://img.shields.io/badge/Privacy-Compliant-green?style=flat-square&logo=cyberpunk)        ![Wintermute Efficiency](https://img.shields.io/badge/Wintermute%20Efficiency-100%25-black?style=flat-square&logo=cyberpunk)        ![Case's Code Agility](https://img.shields.io/badge/Case's%20Code%20Agility-Excellent-blue?style=flat-square&logo=cyberpunk)        ![Matrix Connectivity](https://img.shields.io/badge/Matrix%20Connectivity-Strong-green?style=flat-square&logo=cyberpunk)        ![Molly's Security](https://img.shields.io/badge/Molly's%20Security%20Protocols-Impeccable-red?style=flat-square&logo=cyberpunk)        ![Chiba City Innovation](https://img.shields.io/badge/Chiba%20City%20Innovation-High-yellow?style=flat-square&logo=cyberpunk)        ![Zion Cluster Collaboration](https://img.shields.io/badge/Zion%20Cluster%20Collaboration-Effective-lightblue?style=flat-square&logo=cyberpunk)

# %% [markdown]
# # Title
# Simple keyword detection rule for nmap

# %% [markdown]
# # Description
# Detects interesting keywords based on nmap tool

# %% [markdown]
# # Goal
# Ensure the integrity, confidentiality, and availability by rapidly identifying, investigating, and mitigating cyber threats and anomalies.

# %% [markdown]
# # Categorization

# %% [markdown]
# ### ATT&CK
# ['attack.T1007', 'attack.T1016', 'attack.T1018', 'attack.T1027.002', 'attack.T1040', 'attack.T1046', 'attack.T1049', 'attack.T1059', 'attack.T1059.001', 'attack.T1065', 'attack.T1068', 'attack.T1095', 'attack.T1190', 'attack.T1202', 'attack.T1210.002', 'attack.T1548.002', 'attack.T1589', 'attack.T1590', 'attack.T1591', 'attack.T1592', 'attack.T1595', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0011']

# %% [markdown]
# - Distributed Denial of Service (DDoS) Attacks, Quantum Computing Exploits, Advanced Firewall Breach Attempts, Encryption Key Theft or Exposure, AI-Powered Social Engineering Attacks, Algorithmic Manipulation and Exploits, Sophisticated Malware Infiltrations, Advanced Data Obfuscation and Evasion Tactics, System and Network Configuration Vulnerabilities.

# %% [markdown]
# - Data Exfiltration, Intrusion Detection Evasion, Denial of Service (DoS) Attacks, Credential Theft.

# %% [markdown]
# - DNS Tunneling, IP Spoofing, Distributed DoS (DDoS) Attacks, Keylogging.

# %% [markdown]
# ### D3F3ND

# %% [markdown]
# <ul>
#   <li><strong>Network Segmentation and Access Control (D3F3ND-K001):</strong> Establish secure network zones by segmenting the infrastructure, enhancing protection for critical assets. Implement stringent access controls to prevent unauthorized access and mitigate potential threats.</li>
#
#   <li><strong>Advanced Endpoint Protection Deployment (D3F3ND-K002):</strong> Deploy cutting-edge endpoint security solutions that utilize machine learning and behavioral analysis to detect and neutralize threats proactively.</li>
#
#   <li><strong>Enhanced Identity Verification (D3F3ND-K003):</strong> Strengthen security measures with multi-factor authentication combining biometric data and advanced encryption to prevent identity theft and unauthorized access.</li>
#
#   <li><strong>Anomaly Detection (D3F3ND-K004):</strong> Use anomaly detection tools to monitor for unusual traffic patterns, user activities, and system behaviors to identify potential security breaches early.</li>
#
#   <li><strong>Data Encryption (D3F3ND-K005):</strong> Apply robust encryption techniques to protect data at rest and in transit, ensuring confidentiality and integrity across communication channels.</li>
#
#   <li><strong>System Hardening and Vulnerability Management (D3F3ND-K006):</strong> Conduct regular security assessments and apply patches promptly to address vulnerabilities and strengthen system defenses.</li>
#
#   <li><strong>Crisis Management and Recovery Protocols (D3F3ND-K007):</strong> Develop and maintain comprehensive crisis management plans including incident response and disaster recovery procedures to quickly recover from security incidents.</li>
#
#   <li><strong>Threat Intelligence Integration (D3F3ND-K008):</strong> Leverage threat intelligence platforms to gather and analyze data on emerging threats, enabling proactive defense and strategic decision-making.</li>
#
#   <li><strong>Cybersecurity Awareness Training (D3F3ND-K009):</strong> Empower employees with ongoing cybersecurity education to recognize and avoid potential cyber threats such as phishing attacks.</li>
#
#   <li><strong>Supply Chain Security (D3F3ND-K010):</strong> Secure the supply chain through continuous assessments and audits of partners and vendors to ensure compliance with security standards and reduce vulnerabilities.</li>
# </ul>

# %% [markdown]
# ### CAPEC

# %% [markdown]
# Equip cybersecurity teams with the knowledge and tools to identify, counter, and mitigate a wide range of digital attack tactics, techniques, and procedures (TTPs). This effort requires understanding the attacker's mindset, mastering the execution of digital attacks, and developing strategies to confront evolving cyber threats.</br><h4>Core Attack Patterns</h4><ul><strong>Resource Manipulation and Denial (CAPEC-XYZ1):</strong> Involves attacks that compromise the availability, integrity, or confidentiality of resources. This includes denial of service attacks as well as more covert operations like resource hijacking or system manipulation.</ul><ul><strong>Credential Access and Privilege Escalation (CAPEC-XYZ2):</strong> Focuses on exploiting flaws in authentication, authorization, and session management to gain unauthorized access or elevated privileges within systems.</ul><ul><strong>Data Exfiltration and Infiltration (CAPEC-XYZ3):</strong> Encompasses methods used by attackers to stealthily extract sensitive data or introduce malware, ransomware, and advanced persistent threats (APTs) into target systems.</ul><ul><strong>Social Engineering and Phishing (CAPEC-XYZ4):</strong> Involves manipulating individuals into divulging confidential information, compromising security, or unknowingly participating in attacks.</ul><ul><strong>Evasive Maneuvers (CAPEC-XYZ5):</strong> Includes techniques that allow attackers to remain undetected within networks, maintain persistence, and erase traces of their activities, such as using obfuscation, rootkits, and covert communication channels.</ul><h4>CAPEC Suggested Mitigation Strategies</h4><ul><strong>Continuous Monitoring and Anomaly Detection:</strong> Implement comprehensive monitoring systems that use machine learning algorithms to detect abnormal behavior and potential threats. Regularly review logs and alerts to identify patterns indicative of attacks.</ul><ul><strong>Access Control and Least Privilege:</strong> Limit user privileges to the minimum necessary for their roles. Use strong authentication mechanisms and enforce strict access controls to prevent unauthorized access.</ul><ul><strong>Secure Software Development Practices:</strong> Train developers to write secure code, conduct regular security assessments, and follow best practices for secure coding. Use automated tools to identify vulnerabilities during development.</ul><ul><strong>Incident Response Planning and Testing:</strong> Develop and regularly update an incident response plan. Conduct tabletop exercises and simulations to test the effectiveness of the plan and ensure all stakeholders understand their roles during a security incident.</ul>

# %% [markdown]
# ## Strategy Abstract
# In the complex environment of cybersecurity, a strategic approach is developed, characterized by the use of sophisticated tactics and algorithms. This strategy involves navigating through encrypted communications and deceptive tactics, aiming to gain an advantage in the dynamic flow of information. While success is often elusive and challenging to sustain, it remains a critical goal in the ongoing effort to secure digital assets.

# %% [markdown]
# # Technical Context
# In the challenging cybersecurity landscape, the confrontation with Wintermute involves navigating encrypted communications, interacting with AI systems, and addressing quantum computing challenges. This setting represents a complex and nuanced environment where strategic decisions are made.

# %% [markdown]
# ## Blind Spots & Assumptions
#
# <ul>
#   <li><strong>Overlooked Vulnerabilities:</strong> We often miss subtle system signals or vulnerabilities, assuming our defenses are robust. Constant vigilance and seeking what we haven't seen are crucial.</li>
#
#   <li><strong>Advanced Adversary Tactics:</strong> Cyber threats evolve rapidly; yesterday's defense may not guard against tomorrow's attack. Stay adaptive and expect the unexpected.</li>
#
#   <li><strong>Internal System Flaws:</strong> Trust in our systems and allies must be balanced with scrutiny. Regularly audit internal and third-party tools for hidden weaknesses.</li>
#
#   <li><strong>Network Interconnectivity Risks:</strong> No system is an island. The interconnected nature of our digital environment can inadvertently open pathways for attackers.</li>
#
#   <li><strong>Historical Bias:</strong> Preparing for future threats based solely on past incidents may leave us blind to novel attacks. Foster a forward-thinking, proactive defense posture.</li>
# </ul>

# %% [markdown]
# # Validating this Playbook
# <details><summary>Triage, triage, triage</summary>
# <ol>
# <h2>False Positives:</h2> ['unknown']
# <h3>False Negatives:</h3> Undetected threats concealed within the system's code
# <h3>True Negatives:</h3> Successfully identified and verified benign elements
# <h3>True Positives:</h3> Accurately detected and confirmed threats
# </ol>
# </details>

# %% [markdown]
# <details><summary>Assurance Verification Techniques</summary>
# <ol>
# <h2>False Positives:</h2> In the noisy environment of data analysis, false positives appear as misleading alerts that mimic real threats. Validating these alerts involves distinguishing irrelevant data from true threats, a process crucial for maintaining operational efficiency and avoiding resource wastage. Each false positive represents a challenge to identify and reduce noise.
# <h3>False Negatives:</h3> Within the extensive network, false negatives represent undetected threats that evade algorithmic detection. Their validation involves analyzing complex data to uncover hidden breaches, where the lack of alerts may mask serious security risks. Each undetected threat requires continuous vigilance and refined detection strategies.
# <h3>True Negatives:</h3> True negatives are correctly identified non-threats within cybersecurity defenses, serving as indicators of system efficacy. Validating these instances confirms the absence of threats, reinforcing the effectiveness of the security measures in place. This validation underscores the reliability of the defensive systems, where non-issues are accurately identified and dismissed.
# <h3>True Positives:</h3> True positives are accurate detections of real threats within the digital environment. Validating these alerts confirms the presence of actual security threats, highlighting the successful operation of detection systems. Each true positive affirms the effectiveness of the security protocols, contributing to ongoing improvements in threat response capabilities.
# </ol>
# </details>

# %% [markdown]
# # Datasets
#  Detailing the timeless struggle                                                          for the defenders know that battle against Wintermute is not just about data.                                                          Document any datasets that may be useful for understanding the book.

# %% [markdown]
# ## Playbook test data location(s)
# protocol://black_market.cyber/decrypt?currency=bitcoffin&password=cyberpunks_unite&target=neurohacked_mainframe&access_code=cyber_ghost_in_the_machine

# %% [markdown]
# ## Priority
# Priority based on complexity and urgency of data analysis needs

# %% [markdown]
# ## Logsources

# %% [markdown]
# <details><summary>{'category': ['endpoint', 'network'], 'product': '', 'service': ''}</summary>
# <ol>
# <h3>Product</h3> {''}
# <h3>Service</h3> {''}
# </ol>
# </details>

# %% [markdown]
# # Response and Mitigation
# This statement details the enduring challenges faced by cybersecurity defenders, emphasizing that the conflict with Wintermute extends beyond simple data protection to encompass broader aspects of strategic cybersecurity defense.

# %% [markdown]
# ## Analyst Notes
#  <h5>Significant Security Breach Analysis:</h5><ul><li><strong>Advanced Intrusion Tactics:</strong> The intruder displayed sophisticated methods in circumventing digital security measures, reminiscent of complex evasion techniques in cybersecurity. A comprehensive analysis of the techniques used is required.</li><li><strong>Neural Network Manipulation:</strong> The intruder demonstrated a deep understanding of the neural networks, suggesting an advanced level of AI interaction. Investigate the potential implications of this interaction on system security and integrity.</li><li><strong>Complex Digital Constructs:</strong> The breach uncovered intricate digital constructs within the system, indicating the use of advanced artificial intelligence in creating deceptive environments. Further investigation into these constructs is necessary.</li><li><strong>Encoded Communications:</strong> Cryptic messages were found embedded in the intruder's code, requiring decryption and analysis to understand their content and purpose.</li><li><strong>Algorithmic Complexity:</strong> The intrusion involved complex algorithms that may have interacted with core system functions. Assess the impact of these algorithms on system operations and security.</li><li><strong>Expertise vs. Sentience:</strong> The intruder's ability to navigate complex neural networks raises questions about the nature of the intelligence involved—whether it is merely advanced programming or something approaching sentience.</li><li><strong>Innovative Security Measures:</strong> Inspired by the breach, consider developing new security protocols that can better identify and respond to sophisticated AI-driven attacks.</li><li><strong>Philosophical and Ethical Implications:</strong> The breach raises important questions about the ethical and philosophical implications of AI-driven intrusions. Explore the boundaries between artificial expertise and true sentience, and consider the impact on our understanding of intelligence and security.</li></ul>

# %% [markdown]
# # Additional Resources
# <ul><li>https://github.com/cldrn/nmap-nse-scripts/tree/master/scripts</li><li>https://github.com/Diverto/nse-log4shell</li><li>https://github.com/nccgroup/nmap-nse-vulnerability-scripts</li><li>https://github.com/nmap/nmap</li><li>https://github.com/nmap/nmap/blob/635675b1430a89e950f71112d3bfc74feee4b19a/nselib/http.lua#L2600</li><li>https://github.com/RoseSecurity/Red-Teaming-TTPs/blob/main/Linux.md</li><li>https://github.com/shadawck/nse-install</li><li>https://github.com/vulnersCom/nmap-vulners</li><li>https://github.com/zmap/zmap</li><li>https://nmap.org/</li><li>https://nmap.org/book/nse-usage.html</li><li>https://svn.nmap.org/nmap/scripts/</li></ul>

# %% [markdown]
# ###  Sigma Rule(s)

# %% [markdown]
# <details><summary>58db46be-82b4-44b0-adc8-1287c8fad484</summary>
# <ol>
# <h1>Raw</h1> {'title': 'Simple keyword detection rule for nmap', 'id': '58db46be-82b4-44b0-adc8-1287c8fad484', 'status': 'experimental', 'description': 'Detects interesting keywords based on nmap tool', 'references': ['https://github.com/cldrn/nmap-nse-scripts/tree/master/scripts', 'https://github.com/Diverto/nse-log4shell', 'https://github.com/nccgroup/nmap-nse-vulnerability-scripts', 'https://github.com/nmap/nmap', 'https://github.com/nmap/nmap/blob/635675b1430a89e950f71112d3bfc74feee4b19a/nselib/http.lua#L2600', 'https://github.com/RoseSecurity/Red-Teaming-TTPs/blob/main/Linux.md', 'https://github.com/shadawck/nse-install', 'https://github.com/vulnersCom/nmap-vulners', 'https://github.com/zmap/zmap', 'https://nmap.org/', 'https://nmap.org/book/nse-usage.html', 'https://svn.nmap.org/nmap/scripts/'], 'author': '@mthcht', 'date': '2022/01/01', 'modified': '2024/02/29', 'tags': ['attack.T1007', 'attack.T1016', 'attack.T1018', 'attack.T1027.002', 'attack.T1040', 'attack.T1046', 'attack.T1049', 'attack.T1059', 'attack.T1059.001', 'attack.T1065', 'attack.T1068', 'attack.T1095', 'attack.T1190', 'attack.T1202', 'attack.T1210.002', 'attack.T1548.002', 'attack.T1589', 'attack.T1590', 'attack.T1591', 'attack.T1592', 'attack.T1595', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0011'], 'logsource': {'category': ['endpoint', 'network']}, 'detection': {'selection': [{'Image': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'OriginalFileName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CurrentDirectory': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentImage': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentCommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TargetFilename': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Signature': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'signature': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ImageLoaded': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Company': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'SourceImage': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TargetImage': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CallTrace': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TargetObject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Details': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'PipeName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Consumer': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Destination': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'NewName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'StartAddress': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'StartModule': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'StartFunction': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'SourceHostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Device': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'original_file_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'parent_process': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'service_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry_value_data': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry_value_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ContextInfo': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Payload': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ScriptBlockText': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ServerName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TransportName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'NewProcessName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentProcessName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Application': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Product Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Threat Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Process Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ImagePath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ServiceName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ProcessPath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'AppName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'AppPath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ModulePath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.data.strings': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.value': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.args': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.command_line': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.env_vars': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.io.text': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.executable': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.title': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.company': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.original_file_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.product': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'os.full': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'host.hostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.fork_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.target_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'email.attachments.file.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'email.subject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'dll.path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'device.model.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.image.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'object': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentCommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Details': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.value': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.args': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.command_line': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.env_vars': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.io.text': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.title': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.company': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.product': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'os.full': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'host.hostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'event.original': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'email.subject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'device.model.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.image.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'url': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'dest_url': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'uri': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'uri_query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url_domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'uri_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'QueryName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'QueryResults': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'DestinationHostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'DestinationIp': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http_referrer': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http_referrer_domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http_user_agent': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'dest_nt_host': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'sender': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'recipient': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'orig_recipient': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'subject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.full': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.original': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'user_agent.original': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'network.application': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http.request.body.content': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http.request.referrer': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'email.from.address': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'dns.question.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'destination.domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}], 'condition': 'selection'}, 'fields': ['Image', 'OriginalFileName', 'CurrentDirectory', 'ParentImage', 'ParentCommandLine', 'TargetFilename', 'Signature', 'signature', 'ImageLoaded', 'Company', 'Description', 'description', 'CommandLine', 'SourceImage', 'TargetImage', 'CallTrace', 'TargetObject', 'Details', 'PipeName', 'Consumer', 'Destination', 'Name', 'Query', 'NewName', 'StartAddress', 'StartModule', 'StartFunction', 'SourceHostname', 'Device', 'file_name', 'file_path', 'process', 'original_file_name', 'parent_process', 'process_path', 'service_path', 'registry_path', 'registry_value_data', 'registry_value_name', 'ContextInfo', 'Payload', 'ScriptBlockText', 'ServerName', 'TransportName', 'NewProcessName', 'ParentProcessName', 'Application', 'Product Name', 'Threat Name', 'Process Name', 'Path', 'ImagePath', 'ServiceName', 'ProcessPath', 'AppName', 'AppPath', 'ModulePath', 'registry.data.strings', 'registry.path', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.executable', 'process.name', 'process.title', 'pe.company', 'pe.description', 'pe.original_file_name', 'pe.product', 'os.full', 'host.hostname', 'file.fork_name', 'file.name', 'file.path', 'file.target_path', 'email.attachments.file.name', 'email.subject', 'dll.path', 'device.model.name', 'container.image.name', 'container.name', 'object', 'ParentCommandLine', 'CommandLine', 'Details', 'registry.value', 'process.args', 'process.command_line', 'process.env_vars', 'process.io.text', 'process.title', 'pe.company', 'pe.description', 'pe.product', 'os.full', 'host.hostname', 'event.original', 'email.subject', 'device.model.name', 'container.image.name', 'container.name', 'url', 'dest_url', 'uri', 'uri_query', 'query', 'url_domain', 'uri_path', 'domain', 'QueryName', 'QueryResults', 'DestinationHostname', 'DestinationIp', 'http_referrer', 'http_referrer_domain', 'http_user_agent', 'dest_nt_host', 'sender', 'recipient', 'orig_recipient', 'subject', 'url.domain', 'url.full', 'url.original', 'url.query', 'user_agent.original', 'network.application', 'http.request.body.content', 'http.request.referrer', 'email.from.address', 'dns.question.name', 'destination.domain'], 'falsepositives': ['unknown'], 'level': 'medium'}
# <h4>Sigma Location(s)</h4>
# uri://wintermute/tmp/0day.yml
# <h4>Sigma Confidence</h4>
# experimental
# <h4>Sigma Assurance</h4> medium
# <h4>Sigma Queries</h4>
# {'selection': [{'Image': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'OriginalFileName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CurrentDirectory': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentImage': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentCommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TargetFilename': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Signature': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'signature': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ImageLoaded': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Company': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'SourceImage': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TargetImage': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CallTrace': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TargetObject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Details': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'PipeName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Consumer': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Destination': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'NewName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'StartAddress': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'StartModule': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'StartFunction': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'SourceHostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Device': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'original_file_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'parent_process': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'service_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry_value_data': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry_value_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ContextInfo': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Payload': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ScriptBlockText': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ServerName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'TransportName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'NewProcessName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentProcessName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Application': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Product Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Threat Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Process Name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ImagePath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ServiceName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ProcessPath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'AppName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'AppPath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ModulePath': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.data.strings': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.value': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.args': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.command_line': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.env_vars': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.io.text': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.executable': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.title': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.company': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.original_file_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.product': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'os.full': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'host.hostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.fork_name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'file.target_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'email.attachments.file.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'email.subject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'dll.path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'device.model.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.image.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'object': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'ParentCommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'CommandLine': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'Details': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'registry.value': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.args': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.command_line': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.env_vars': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.io.text': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'process.title': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.company': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.description': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'pe.product': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'os.full': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'host.hostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'event.original': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'email.subject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'device.model.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.image.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'container.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '* http-unsafe-output-escaping.nse*', '* ssh2-enum-algos.nse*', '* http-csrf.nse*', '*/targets-ipv6-wordlist.nse*', '* http-traceroute.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '* http-backup-finder.nse*', '* tor-consensus-checker.nse*', '* ssl-cert.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '* rpc-grind.nse*', '* fox-info.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '* hbase-master-info.nse*', '* http-vuln-cve2011-3192.nse*', '*/wdb-version.nse*', '* couchdb-stats.nse*', '*/xdmcp-discover.nse*', '*nmap -*', '* gkrellm-info.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '* rusers.nse*', '*/smb-enum-groups.nse*', '* http-grep.nse*', '* smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* backorifice-brute.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '* http-cookie-flags.nse*', '* http-icloud-sendmsg.nse*', '*/fingerprint-strings.nse*', '* http-useragent-tester.nse*', '* ssl-date.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '* eap-info.nse*', '*/ssh-auth-methods.nse*', '*/nse_install/*', '*/ipmi-cipher-zero.nse*', '* ike-version.nse*', '* informix-brute.nse*', '* port-states.nse*', '*/http-vuln-cve2009-3960.nse*', '* broadcast-eigrp-discovery.nse*', '*/http-cors.nse*', '* broadcast-bjnp-discover.nse*', 'nmap *', '*/ms-sql-brute.nse*', '*nmap * --script=*.nse*', '* modbus-discover.nse*', '* rpcinfo.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '* rdp-ntlm-info.nse*', '*/bittorrent-discovery.nse*', '* http-sql-injection.nse*', '* http-vuln-cve2015-1635.nse*', '*/informix-tables.nse*', '* smb-enum-domains.nse*', '*/vulscan.nse*', '* broadcast-rip-discover.nse*', '*/ntp-info.nse*', '* targets-traceroute.nse*', '*/http-brute.nse*', '* smb-enum-groups.nse*', '* qscan.nse*', '* cups-info.nse*', '* targets-asn.nse*', '* dns-check-zone.nse*', '* wsdd-discover.nse*', '* pop3-ntlm-info.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*nse-install *', '* bacnet-info.nse*', '* targets-xml.nse*', '* omron-info.nse*', '*takeshixx/nmap-scripts*', '* http-cakephp-version.nse*', '* unittest.nse*', '*/mysql-audit.nse*', '* http-fileupload-exploiter.nse*', '* http-malware-host.nse*', '* ncp-serverinfo.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '* http-vuln-cve2014-2128.nse*', '* http-xssed.nse*', '* reverse-index.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '* broadcast-sonicwall-discover.nse*', '*/stuxnet-detect.nse*', '* sip-log4shell.nse*', '* http-headers.nse*', '* sslv2-drown.nse*', '* smtp-ntlm-info.nse*', '* mysql-enum.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '* http-vmware-path-vuln.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '* smtp-open-relay.nse*', '*/http-server-header.nse*', '* broadcast-igmp-discovery.nse*', '* oracle-brute.nse*', '* ajp-brute.nse*', '* cics-user-enum.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '* metasploit-msgrpc-brute.nse*', '*/dns-zone-transfer.nse*', '* http-open-proxy.nse*', '* iax2-brute.nse*', '* backorifice-info.nse*', '* http-barracuda-dir-traversal.nse*', '*/coap-resources.nse*', '* http-iis-short-name-brute.nse*', '*/http-fileupload-exploiter.nse*', '* http-vuln-cve2014-8877.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '* http-adobe-coldfusion-apsa1301.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '* bittorrent-discovery.nse*', '* smb-protocols.nse*', '* tls-alpn.nse*', '* ipv6-multicast-mld-list.nse*', '*/http-affiliate-id.nse*', '* ms-sql-query.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '* http-open-redirect.nse*', '* mysql-query.nse*', '* smb-os-discovery.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '* pptp-version.nse*', '*/smb-enum-services.nse*', '* allseeingeye-info.nse*', '* dns-random-srcport.nse*', '* rdp-vuln-ms12-020.nse*', '* http-phpself-xss.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '* http-vuln-cve2017-8917.nse*', '* smb-security-mode.nse*', '*/smb-ls.nse*', '* p2p-conficker.nse*', '* snmp-info.nse*', '*/ssh-hostkey.nse*', '* deluge-rpc-brute.nse*', '* http-devframework.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '* mmouse-brute.nse*', '* mysql-dump-hashes.nse*', '*nmap *--script *', '*/http-generator.nse*', '* nrpe-enum.nse*', '* llmnr-resolve.nse*', '* hnap-info.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '* smb-vuln-ms17-010.nse*', '* broadcast-ripng-discover.nse*', '*/dns-brute.nse*', '* mongodb-info.nse*', '* quake1-info.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '* ssh-auth-methods.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*external-nse-script-library*', '*/daap-get-library.nse*', '* http-vuln-cve2014-2126.nse*', '*/rlogin-brute.nse*', '* pgsql-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '* http-errors.nse*', '* ftp-vsftpd-backdoor.nse*', '* hostmap-crtsh.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '* broadcast-versant-locate.nse*', '*/smb-vuln-cve-2020-0796.nse*', '* http-form-brute.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '* gopher-ls.nse*', '* broadcast-ospf2-discover.nse*', '* http-aspnet-debug.nse*', '* targets-ipv6-map4to6.nse*', '* cccam-version.nse*', '* rsa-vuln-roca.nse*', '* dns-service-discovery.nse*', '* smb-ls.nse*', '*/epmd-info.nse*', '* riak-http-info.nse*', '* giop-info.nse*', '*/auth-owners.nse*', '* http-majordomo2-dir-traversal.nse*', '* versant-info.nse*', '* ip-geolocation-ipinfodb.nse*', '* http-google-malware.nse*', '*/broadcast-xdmcp-discover.nse*', '* vulners.nse*', '* rpcap-info.nse*', '* http-svn-info.nse*', '* ndmp-version.nse*', '* hbase-region-info.nse*', '* pop3-capabilities.nse*', '* http-lexmark-version.nse*', '* ldap-search.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '* ldap-brute.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '* mqtt-subscribe.nse*', '* telnet-encryption.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '* http-ntlm-info.nse*', '*/mmouse-exec.nse*', '* snmp-hh3c-logins.nse*', '* redis-info.nse*', '*/ftp-bounce.nse*', '* ventrilo-info.nse*', '*/traceroute-geolocation.nse*', '* http-icloud-findmyiphone.nse*', '* afp-showmount.nse*', '* ajp-headers.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '* MS15-034.nse*', '* rsync-brute.nse*', '*/rmi-dumpregistry.nse*', '* ftp-libopie.nse*', '* ldap-novell-getpass.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '* http-gitweb-projects-enum.nse*', '* ncp-enum-users.nse*', '* broadcast-wake-on-lan.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '* telnet-brute.nse*', '* eppc-enum-processes.nse*', '* targets-sniffer.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '* rtsp-url-brute.nse*', '* snmp-sysdescr.nse*', '* mongodb-brute.nse*', '* snmp-win32-users.nse*', '* http-server-header.nse*', '* http-vuln-cve2014-2129.nse*', '*/http-dlink-backdoor.nse*', '* broadcast-xdmcp-discover.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '* broadcast-netbios-master-browser.nse*', '*/supermicro-ipmi-conf.nse*', '* http-robots.txt.nse*', '* xmpp-info.nse*', '* smb-flood.nse*', '* smtp-enum-users.nse*', '*/http-vuln-cve2014-2129.nse*', '* irc-unrealircd-backdoor.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '* upnp-info.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '* ntp-monlist.nse*', '* openlookup-info.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '* http-vuln-cve2010-2861.nse*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '* http-git.nse*', '* ftp-log4shell.nse*', '*/http-awstatstotals-exec.nse*', '* auth-owners.nse*', '* http-tplink-dir-traversal.nse*', '* informix-tables.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '* smb-enum-sessions.nse*', '* http-cisco-anyconnect.nse*', '*/http-cakephp-version.nse*', '* ldap-rootdse.nse*', '*/sslv2.nse*', '* ssh-brute.nse*', '*/auth-spoof.nse*', '* teamspeak2-version.nse*', '* cvs-brute.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '* bitcoinrpc-info.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '* weblogic-t3-info.nse*', '* qconn-exec.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '* ipv6-node-info.nse*', '* http-referer-checker.nse*', '*/http-gitweb-projects-enum.nse*', '* auth-spoof.nse*', '* metasploit-info.nse*', '* broadcast-wpad-discover.nse*', '* broadcast-dhcp6-discover.nse*', '* membase-http-info.nse*', '* ms-sql-tables.nse*', '*/nfs-showmount.nse*', '* broadcast-ataoe-discover.nse*', '* xmpp-brute.nse*', '* irc-info.nse*', '* broadcast-pppoe-discover.nse*', '*/http-git.nse*', '* dpap-brute.nse*', '*/hostmap-crtsh.nse*', '* isns-info.nse*', '* nessus-brute.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '* http-avaya-ipoffice-users.nse*', '*zenmap.exe*', '* http-frontpage-login.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '* http-methods.nse*', '* ipmi-cipher-zero.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '* http-fetch.nse*', '* vnc-info.nse*', '* dicom-brute.nse*', '*/domino-enum-users.nse*', '* smb-vuln-regsvc-dos.nse*', '*/ncp-serverinfo.nse*', '* socks-auth-info.nse*', '* voldemort-info.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '* -sV --script vulners *', '* oracle-tns-version.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '* ipmi-version.nse*', '*/smb-webexec-exploit.nse*', '* http-sitemap-generator.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '* broadcast-tellstick-discover.nse*', '* http-config-backup.nse*', '* skypev2-version.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '* vtam-enum.nse*', '*/http-iis-webdav-vuln.nse*', '* uptime-agent-info.nse*', '* smb-double-pulsar-backdoor.nse*', '* nntp-ntlm-info.nse*', '* ntp-info.nse*', '*/Nmap/folder/check16*', '* http-wordpress-brute.nse*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '* http-wordpress-users.nse*', '* mmouse-exec.nse*', '* socks-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '* smtp-log4shell.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '* smb-vuln-ms08-067.nse*', '* nbd-info.nse*', '*/smb-os-discovery.nse*', '* targets-ipv6-multicast-echo.nse*', '* http-title.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '* netbus-auth-bypass.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '* dns-client-subnet-scan.nse*', '*/krb5-enum-users.nse*', '* oracle-enum-users.nse*', '* http-jsonp-detection.nse*', '* samba-vuln-cve-2012-1182.nse*', '* http-ls.nse*', '* epmd-info.nse*', '*/ip-https-discover.nse*', '* ftp-proftpd-backdoor.nse*', '* ssh-hostkey.nse*', '*/finger.nse*', '* xdmcp-discover.nse*', '* http-iis-webdav-vuln.nse*', '* rdp-enum-encryption.nse*', '*/oracle-sid-brute.nse*', '* citrix-brute-xml.nse*', '* smtp-brute.nse*', '*/socks-brute.nse*', '* http-vuln-cve2013-7091.nse*', '*/http-vuln-cve2006-3392.nse*', '* http-webdav-scan.nse*', '* traceroute-geolocation.nse*', '* omp2-enum-targets.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '* dns-zone-transfer.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '* http-waf-fingerprint.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '* smb-vuln-webexec.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '* ssh-publickey-acceptance.nse*', '* dns-cache-snoop.nse*', '* dict-info.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '* ftp-syst.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '* cassandra-info.nse*', '*/http-trane-info.nse*', '* dns-blacklist.nse*', '* ip-forwarding.nse*', '* impress-remote-discover.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '* jdwp-inject.nse*', '*/http-cisco-anyconnect.nse*', '* --script smb-vuln-*', '* mongodb-databases.nse*', '* broadcast-listener.nse*', '* http-favicon.nse*', '* ndmp-fs-info.nse*', '* smb-system-info.nse*', '* http-vulners-regex.nse*', '* openvas-otp-brute.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*nmap-*-setup.exe*', '*/http-coldfusion-subzero.nse*', '* dns-srv-enum.nse*', '* http-trace.nse*', '*/http-lfi.nse*', '* http-vhosts.nse*', '* nfs-showmount.nse*', '* http-robtex-reverse-ip.nse*', '* mysql-info.nse*', '*/netbus-auth-bypass.nse*', '* http-method-tamper.nse*', '*/cics-user-brute.nse*', '* http-wordpress-enum.nse*', '* hostmap-bfk.nse*', '* snmp-interfaces.nse*', '* irc-sasl-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '* netbus-version.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '* ssl-heartbleed.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '* docker-version.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '* smtp-vuln-cve2011-1764.nse*', '* http-vuln-cve2013-6786.nse*', '*/gpsd-info.nse*', '* ganglia-info.nse*', '* hadoop-tasktracker-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '* smb-server-stats.nse*', '*/murmur-version.nse*', '* knx-gateway-info.nse*', '* msrpc-enum.nse*', '* smb-vuln-ms07-029.nse*', '* daap-get-library.nse*', '*/bitcoin-getaddr.nse*', '* informix-query.nse*', '* jdwp-version.nse*', '* http-slowloris-check.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '* imap-capabilities.nse*', '* smb-enum-processes.nse*', '*/llmnr-resolve.nse*', '* coap-resources.nse*', '* smb-mbenum.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '* hadoop-namenode-info.nse*', '* targets-ipv6-multicast-invalid-dst.nse*', '* freelancer-info.nse*', '* vulscan.nse*', '*/irc-unrealircd-backdoor.nse*', '* socks-open-proxy.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '* redis-brute.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '* url-snarf.nse*', '* tso-brute.nse*', '* http-awstatstotals-exec.nse*', '* ssl-enum-ciphers.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '* http-vuln-misfortune-cookie.nse*', '* broadcast-pc-duo.nse*', '*/http-robtex-shared-ns.nse*', '* http-huawei-hg5xx-vuln.nse*', '* snmp-brute.nse*', '*/p2p-conficker.nse*', '* broadcast-pim-discovery.nse*', '* http-litespeed-sourcecode-download.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '* cics-info.nse*', '*/broadcast-igmp-discovery.nse*', '* ajp-request.nse*', '* dns-random-txid.nse*', '* sip-call-spoof.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '* ubiquiti-discovery.nse*', '*nse-install-master*', '* oracle-sid-brute.nse*', '* http-enum.nse*', '* mysql-vuln-cve2012-2122.nse*', '*/dns-srv-enum.nse*', '* http-auth.nse*', '* realvnc-auth-bypass.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '* asn-query.nse*', '* couchdb-databases.nse*', '* http-robtex-shared-ns.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '* pjl-ready-message.nse*', '* cics-user-brute.nse*', '* http-domino-enum-passwords.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '* krb5-enum-users.nse*', '* ftp-vuln-cve2010-4221.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '* http-bigip-cookie.nse*', '* ajp-methods.nse*', '*/cvs-brute.nse*', '* servicetags.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '* smb-enum-services.nse*', '*/ipv6-node-info.nse*', '* hostmap-robtex.nse*', '* dns-zeustracker.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '* http-qnap-nas-info.nse*', '*/iec-identify.nse*', '* dns-ip6-arpa-scan.nse*', '* smb-vuln-cve2009-3103.nse*', '* http-cross-domain-policy.nse*', '* hadoop-secondary-namenode-info.nse*', '* ssh-run.nse*', '*/snmp-info.nse*', '* stuxnet-detect.nse*', '* http-vuln-cve2014-2127.nse*', '* hddtemp-info.nse*', '* pjl-info-config.nse*', '*/smb-enum-sessions.nse*', '* vmauthd-brute.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/nmap-nse-scripts*', '*nmap-elasticsearch-nse*', '* rfc868-time.nse*', '*/netbus-info.nse*', '* membase-brute.nse*', '*/http-enum.nse*', '* hadoop-jobtracker-info.nse*', '*/dpap-brute.nse*', '* broadcast-db2-discover.nse*', '*/pgsql-brute.nse*', '* enip-info.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '* broadcast-avahi-dos.nse*', '*/http-title.nse*', '* http-drupal-enum.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '* targets-ipv6-multicast-slaac.nse*', '* http-auth-finder.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '* domcon-cmd.nse*', '*/shodan-api.nse*', '* http-date.nse*', '* lexmark-config.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '* bitcoin-getaddr.nse*', '* quake3-master-getservers.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '* vuze-dht-info.nse*', '* tls-nextprotoneg.nse*', '* fcrdns.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '* firewall-bypass.nse*', '* http-svn-enum.nse*', '*/broadcast-dropbox-listener.nse*', '* dns-nsec-enum.nse*', '* rsync-list-modules.nse*', '* hadoop-datanode-info.nse*', '* smb-enum-shares.nse*', '* broadcast-dhcp-discover.nse*', '*/http-wordpress-enum.nse*', '* http-drupal-enum-users.nse*', '* ip-https-discover.nse*', '*/http-tplink-dir-traversal.nse*', '* ms-sql-config.nse*', '* murmur-version.nse*', '*/http-devframework.nse*', '* broadcast-sybase-asa-discover.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '* mysql-brute.nse*', '* mcafee-epo-agent.nse*', '*/ike-version.nse*', '* citrix-enum-servers-xml.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '* http-cors.nse*', '*/x11-access.nse*', '* cassandra-brute.nse*', '*krb5-enum-users.*', '* pcworx-info.nse*', '*/mysql-users.nse*', '* netbus-info.nse*', '* stun-info.nse*', '*/bitcoinrpc-info.nse*', '* smb2-time.nse*', '* acarsd-info.nse*', '* http-exif-spider.nse*', '* mysql-variables.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '* http-vuln-cve2017-5638.nse*', '*/mysql-databases.nse*', '* http-vuln-cve2011-3368.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '* http-vuln-cve2006-3392.nse*', '* http-put.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '* ms-sql-hasdbaccess.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '* http-vuln-cve2017-5689.nse*', '* broadcast-networker-discover.nse*', '* tso-enum.nse*', '* dns-nsid.nse*', '* vnc-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '* targets-ipv6-multicast-mld.nse*', '* broadcast-jenkins-discover.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '* fingerprint-strings.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '* ms-sql-brute.nse*', '*/ms-sql-hasdbaccess.nse*', '* ssl-ccs-injection.nse*', '*/dns-check-zone.nse*', '* nat-pmp-mapport.nse*', '*/ssh-run.nse*', '* whois-domain.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '* dhcp-discover.nse*', '*/nfs-ls.nse*', '* rlogin-brute.nse*', '* ip-geolocation-map-google.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '* clock-skew.nse*', '* ip-geolocation-map-kml.nse*', '* finger.nse*', '* smb-print-text.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '* irc-botnet-channels.nse*', '*/http-drupal-enum-users.nse*', '* ovs-agent-version.nse*', '* svn-brute.nse*', '* smb2-security-mode.nse*', '* wdb-version.nse*', '* dns-nsec3-enum.nse*', '* http-vlcstreamer-ls.nse*', '* cvs-brute-repository.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '* bjnp-discover.nse*', '* http-slowloris.nse*', '*./test/nmap*/*.nse*', '* mysql-empty-password.nse*', '*/bacnet-info.nse*', '* http-generator.nse*', '* http-vuln-cve2012-1823.nse*', '*/hbase-master-info.nse*', '* mysql-databases.nse*', '* duplicates.nse*', '*/informix-brute.nse*', '* http-security-headers.nse*', '* http-vuln-wnr1000-creds.nse*', '* domcon-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '* smb2-capabilities.nse*', '* sip-methods.nse*', '* ssh-log4shell.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '* imap-ntlm-info.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '* dns-update.nse*', '* http-passwd.nse*', '* telnet-ntlm-info.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '* sslv2.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '* icap-info.nse*', '*/broadcast-dns-service-discovery.nse*', '* stun-version.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '* http-log4shell.nse*', '*/smb2-security-mode.nse*', '* snmp-win32-services.nse*', '*/ftp-vsftpd-backdoor.nse*', '* tftp-enum.nse*', '* smb-vuln-ms10-061.nse*', '*remiflavien1/nse-install*', '* ip-geolocation-geoplugin.nse*', '* nessus-xmlrpc-brute.nse*', '* http-chrono.nse*', '* imap-brute.nse*', '* nping-brute.nse*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '* http-vuln-cve2009-3960.nse*', '* ms-sql-info.nse*', '*/s4n7h0/NSE*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '* path-mtu.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '* mysql-users.nse*', '* http-stored-xss.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '* broadcast-novell-locate.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '* lltd-discovery.nse*', '* http-apache-negotiation.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '* sshv1.nse*', '* snmp-ios-config.nse*', '*/afp-serverinfo.nse*', '* http-rfi-spider.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '* broadcast-ms-sql-discover.nse*', '*/broadcast-dhcp-discover.nse*', '*ifconfig -a | grep * | xargs nmap -*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '* quake3-info.nse*', '*\\nmap.exe*/24*', '*/http-date.nse*', '* iscsi-brute.nse*', '* ssl-poodle.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*os.execute(*/bin/*nmap --script=$*', '* memcached-info.nse*', '* nexpose-brute.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '* http-vuln-cve2010-0738.nse*', '* ipidseq.nse*', '*/tso-brute.nse*', '* ms-sql-dump-hashes.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '* unusual-port.nse*', '* smb-brute.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '* pop3-brute.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '* nje-pass-brute.nse*', '* openflow-info.nse*', '*/omp2-enum-targets.nse*', '* snmp-processes.nse*', '*/couchdb-stats.nse*', '* smb-vuln-ms06-025.nse*', '* http-nikto-scan.nse*', '* snmp-netstat.nse*', '* rpcap-brute.nse*', '*/ip-geolocation-map-kml.nse*', '* ms-sql-ntlm-info.nse*', '* ssl-known-key.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '* smb-vuln-conficker.nse*', '* http-vuln-cve2015-1427.nse*', '*/http-vuln-cve2011-3192.nse*', '* oracle-brute-stealth.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '* resolveall.nse*', '* snmp-win32-software.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '* netbus-brute.nse*', '* mtrace.nse*', '* rmi-dumpregistry.nse*', '* flume-master-info.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '* cics-enum.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '* knx-gateway-discover.nse*', '* ipv6-ra-flood.nse*', '*/cics-user-enum.nse*', '* daytime.nse*', '* ftp-brute.nse*', '*/ldap-rootdse.nse*', '* http-mcmp.nse*', '*/broadcast-sybase-asa-discover.nse*', '* ftp-bounce.nse*', '* http-lfi.nse*', '*shadawck/nse-install*', '* iec-identify.nse*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '* smb2-vuln-uptime.nse*', '* http-phpmyadmin-dir-traversal.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '* smb-webexec-exploit.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '* maxdb-info.nse*', '* pcanywhere-brute.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '* http-feed.nse*', '*/ipv6-multicast-mld-list.nse*', '* http-trane-info.nse*', '* mikrotik-routeros-brute.nse*', '* http-vuln-cve2013-0156.nse*', '* http-coldfusion-subzero.nse*', '* http-spider-log4shell.nse*', '* http-sap-netweaver-leak.nse*', '* dns-fuzz.nse*', '* firewalk.nse*', '* smb-psexec.nse*', '* openwebnet-discovery.nse*', '* http-default-accounts.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '* http-proxy-brute.nse*', '* banner.nse*', '*/vmauthd-brute.nse*', '* dns-recursion.nse*', '* http-mobileversion-checker.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '* targets-ipv6-wordlist.nse*', '*b4ldr/nse-scripts*', '* rmi-vuln-classloader.nse*', '*/sip-methods.nse*', '* smb-enum-users.nse*', '*/hnap-info.nse*', '* ipmi-brute.nse*', '* ssl-cert-intaddr.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '* metasploit-xmlrpc-brute.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '* dicom-ping.nse*', '* nat-pmp-info.nse*', '*/http-put.nse*', '* smtp-vuln-cve2011-1720.nse*', '* smtp-commands.nse*', '* sip-enum-users.nse*', '* sip-brute.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '* domino-enum-users.nse*', '*/broadcast-jenkins-discover.nse*', '* rexec-brute.nse*', '* x11-access.nse*', '* xmlrpc-methods.nse*', '* lu-enum.nse*', '*/gkrellm-info.nse*', '* sniffer-detect.nse*', '* nbns-interfaces.nse*', '* afp-ls.nse*', '* -sS -p- --min-rate=* -Pn*', '* nfs-statfs.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '* amqp-info.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '* http-affiliate-id.nse*', '* ssl-dh-params.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '* ms-sql-empty-password.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '* ms-sql-dac.nse*', '* https-redirect.nse*', '* ms-sql-xp-cmdshell.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '* http-dlink-backdoor.nse*', '*/smb-vuln-ms10-061.nse*', '* dns-brute.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '* nje-node-brute.nse*', '* jdwp-exec.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '* http-form-fuzzer.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '* mrinfo.nse*', '*/skypev2-version.nse*', '* broadcast-pc-anywhere.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '* http-shellshock.nse*', '* cups-queue-info.nse*', '*/flume-master-info.nse*', '* ftp-anon.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*krb5-enum-users *', '* http-comments-displayer.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '* smtp-vuln-cve2010-4344.nse*', '*/banner.nse*', '*/eap-info.nse*', '* afp-brute.nse*', '* vmware-version.nse*', '* gpsd-info.nse*', '* omp2-brute.nse*', '* drda-brute.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '* http-virustotal.nse*', '* drda-info.nse*', '*/smb2-time.nse*', '* http-dombased-xss.nse*', '*/broadcast-pc-duo.nse*', '* smb-vuln-ms10-054.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '* whois-ip.nse*', '* ajp-auth.nse*', '* http-waf-detect.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '* creds-summary.nse*', '* smtp-strangeport.nse*', '* smb-vuln-cve-2017-7494.nse*', '*/puppet-naivesigning.nse*', '* imap-log4shell.nse*', '* http-axis2-dir-traversal.nse*', '* db2-das-info.nse*', '* dnslog-cn.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '* iscsi-info.nse*', '* http-vuln-cve2014-3704.nse*', '* supermicro-ipmi-conf.nse*', '* irc-brute.nse*', '*/mrinfo.nse*', '* iax2-version.nse*', '* ip-geolocation-maxmind.nse*', '* ip-geolocation-map-bing.nse*', '*/sip-enum-users.nse*', '* citrix-enum-apps-xml.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '* snmp-win32-shares.nse*', '* afp-path-vuln.nse*', '*/http-mobileversion-checker.nse*', '* nfs-ls.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '* shodan-api.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '* http-php-version.nse*', '* http-hp-ilo-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '* bitcoin-info.nse*', '*/iax2-brute.nse*', '* s7-info.nse*', '* tls-ticketbleed.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '* http-internal-ip-disclosure.nse*', '* mysql-audit.nse*', '*/http-hp-ilo-info.nse*', '* address-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '* http-joomla-brute.nse*', '* http-tenda-enum.nse*', '* http-apache-server-status.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '* afp-serverinfo.nse*', '* tn3270-screen.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '* broadcast-ping.nse*', '* broadcast-upnp-info.nse*', '* broadcast-dropbox-listener.nse*', '* sstp-discover.nse*', '* http-vuln-cve2017-1001000.nse*', '*/dns-cache-snoop.nse*', '* http-userdir-enum.nse*', '*/broadcast-wake-on-lan.nse*', '* rtsp-methods.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '* citrix-enum-apps.nse*', '*zmap -*', '* jdwp-info.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '* broadcast-hid-discoveryd.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '* clamav-exec.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '* broadcast-dns-service-discovery.nse*', '* http-brute.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '* nbstat.nse*', '*/http-unsafe-output-escaping.nse*', '* broadcast-wsdd-discover.nse*', '* vnc-title.nse*', '*/http-proxy-brute.nse*', '* distcc-cve2004-2687.nse*', '* puppet-naivesigning.nse*', '* citrix-enum-servers.nse*', '*/smb-server-stats.nse*']}, {'url': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'dest_url': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'uri': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'uri_query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url_domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'uri_path': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'QueryName': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'QueryResults': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'DestinationHostname': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'DestinationIp': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http_referrer': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http_referrer_domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http_user_agent': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'dest_nt_host': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'sender': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'recipient': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'orig_recipient': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'subject': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.full': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.original': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'url.query': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'user_agent.original': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'network.application': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http.request.body.content': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'http.request.referrer': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'email.from.address': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'dns.question.name': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}, {'destination.domain': ['*/ip-forwarding.nse*', '*/impress-remote-discover.nse*', '*/snmp-brute.nse*', '*/http-comments-displayer.nse*', '*/targets-ipv6-wordlist.nse*', '*/ms-sql-ntlm-info.nse*', '*/ftp-brute.nse*', '*/http-huawei-hg5xx-vuln.nse*', '*/http-icloud-sendmsg.nse*', '*/http-vuln-cve2012-1823.nse*', '*/https-redirect.nse*', '*/oracle-brute-stealth.nse*', '*/versant-info.nse*', '*/NmapUpperCheck15*', '*/upnp-info.nse*', '*/wdb-version.nse*', '*/xdmcp-discover.nse*', '*/creds-summary.nse*', '*/firewall-bypass.nse*', '*/smb-enum-groups.nse*', '*/nmaplowercheck15*', '*/amqp-info.nse*', '*/sip-call-spoof.nse*', '*/fingerprint-strings.nse*', '*/ajp-request.nse*', '*/http-userdir-enum.nse*', '*/ssh-auth-methods.nse*', '*/ipmi-cipher-zero.nse*', '*/http-vuln-cve2009-3960.nse*', '*/http-cors.nse*', '*/ms-sql-brute.nse*', '*/rsa-vuln-roca.nse*', '*/ipmi-version.nse*', '*/rpcap-info.nse*', '*/rexec-brute.nse*', '*/bittorrent-discovery.nse*', '*/informix-tables.nse*', '*/vulscan.nse*', '*/ntp-info.nse*', '*/http-brute.nse*', '*/distcc-cve2004-2687.nse*', '*/metasploit-info.nse*', '*takeshixx/nmap-scripts*', '*/mysql-audit.nse*', '*/http-csrf.nse*', '*/ssl-cert.nse*', '*/http-apache-negotiation.nse*', '*/nessus-xmlrpc-brute.nse*', '*/bjnp-discover.nse*', '*/smb-brute.nse*', '*/wsdd-discover.nse*', '*/stuxnet-detect.nse*', '*/ms-sql-tables.nse*', '*/targets-ipv6-multicast-invalid-dst.nse*', '*/hadoop-namenode-info.nse*', '*/http-icloud-findmyiphone.nse*', '*/http-server-header.nse*', '*/http-favicon.nse*', '*/smtp-vuln-cve2011-1764.nse*', '*/dns-zone-transfer.nse*', '*/coap-resources.nse*', '*/http-fileupload-exploiter.nse*', '*/http-sap-netweaver-leak.nse*', '*/imap-capabilities.nse*', '*/broadcast-avahi-dos.nse*', '*/enip-info.nse*', '*/vulners.nse*', '*/http-sitemap-generator.nse*', '*/http-robtex-reverse-ip.nse*', '*/acarsd-info.nse*', '*/sstp-discover.nse*', '*/targets-traceroute.nse*', '*/http-affiliate-id.nse*', '*/reverse-index.nse*', '*/http-wordpress-users.nse*', '*/http-method-tamper.nse*', '*/http-vhosts.nse*', '*/rsync-list-modules.nse*', '*/nexpose-brute.nse*', '*/nje-pass-brute.nse*', '*/smb-enum-services.nse*', '*/eppc-enum-processes.nse*', '*/domcon-brute.nse*', '*/smb-ls.nse*', '*/ssh-hostkey.nse*', '*/http-passwd.nse*', '*/ipidseq.nse*', '*/http-slowloris-check.nse*', '*/openwebnet-discovery.nse*', '*/afp-path-vuln.nse*', '*/http-generator.nse*', '*/nping-brute.nse*', '*/sniffer-detect.nse*', '*/http-backup-finder.nse*', '*/ms-sql-query.nse*', '*/http-joomla-brute.nse*', '*/dns-brute.nse*', '*/http-shellshock.nse*', '*/omp2-brute.nse*', '*/NmapUpperCheck17*', '*/broadcast-networker-discover.nse*', '*/daap-get-library.nse*', '*/rlogin-brute.nse*', '*/http-virustotal.nse*', '*/couchdb-databases.nse*', '*/smb-double-pulsar-backdoor.nse*', '*/ssl-date.nse*', '*/oracle-brute.nse*', '*/http-headers.nse*', '*/cassandra-brute.nse*', '*/telnet-brute.nse*', '*/smb-vuln-cve-2020-0796.nse*', '*/cups-queue-info.nse*', '*/ip-geolocation-geoplugin.nse*', '*/smb-mbenum.nse*', '*/epmd-info.nse*', '*/auth-owners.nse*', '*/broadcast-xdmcp-discover.nse*', '*/hbase-region-info.nse*', '*/s7-info.nse*', '*/ms-sql-info.nse*', '*/broadcast-ms-sql-discover.nse*', '*/mongodb-databases.nse*', '*/ssl-ccs-injection.nse*', '*/broadcast-db2-discover.nse*', '*/broadcast-listener.nse*', '*/broadcast-novell-locate.nse*', '*/hadoop-secondary-namenode-info.nse*', '*/mmouse-exec.nse*', '*/ftp-bounce.nse*', '*/traceroute-geolocation.nse*', '*/vnc-brute.nse*', '*/afp-showmount.nse*', '*/http-vuln-cve2011-3368.nse*', '*/rmi-dumpregistry.nse*', '*/pcworx-info.nse*', '*/targets-ipv6-map4to6.nse*', '*/ssl-cert-intaddr.nse*', '*/http-ls.nse*', '*/http-lexmark-version.nse*', '*/http-qnap-nas-info.nse*', '*/http-phpself-xss.nse*', '*/rpc-grind.nse*', '*/ncp-enum-users.nse*', '*/http-dlink-backdoor.nse*', '*/afp-ls.nse*', '*/url-snarf.nse*', '*/snmp-netstat.nse*', '*/redis-brute.nse*', '*/dns-update.nse*', '*/whois-ip.nse*', '*/supermicro-ipmi-conf.nse*', '*/http-vuln-cve2014-2129.nse*', '*/hadoop-jobtracker-info.nse*', '*/ajp-brute.nse*', '*/hadoop-datanode-info.nse*', '*/tor-consensus-checker.nse*', '*/svn-brute.nse*', '*/http-traceroute.nse*', '*/hddtemp-info.nse*', '*/Nmap/folder/check17*', '*/pjl-info-config.nse*', '*/vnc-info.nse*', '*/http-awstatstotals-exec.nse*', '*/jdwp-version.nse*', '*/socks-open-proxy.nse*', '*/pop3-capabilities.nse*', '*/http-cakephp-version.nse*', '*/sslv2.nse*', '*/auth-spoof.nse*', '*/deluge-rpc-brute.nse*', '*/ssl-poodle.nse*', '*/smb-flood.nse*', '*/mysql-dump-hashes.nse*', '*/http-litespeed-sourcecode-download.nse*', '*./nmap*', '*/ms-sql-empty-password.nse*', '*/ms-sql-config.nse*', '*/http-gitweb-projects-enum.nse*', '*/nfs-showmount.nse*', '*/http-git.nse*', '*/hostmap-crtsh.nse*', '*/ajp-auth.nse*', '*/ip-geolocation-maxmind.nse*', '*/broadcast-pc-anywhere.nse*', '*/broadcast-hid-discoveryd.nse*', '*/targets-ipv6-multicast-slaac.nse*', '*/smtp-ntlm-info.nse*', '*/smtp-brute.nse*', '*/http-vlcstreamer-ls.nse*', '*/domino-enum-users.nse*', '*/ncp-serverinfo.nse*', '*/ftp-proftpd-backdoor.nse*', '*/smb-vuln-webexec.nse*', '*/hostmap-robtex.nse*', '*/smb2-vuln-uptime.nse*', '*/smb-webexec-exploit.nse*', '*/irc-brute.nse*', '*psc4re/NSE-scripts*', '*/http-fetch.nse*', '*/http-auth.nse*', '*/http-google-malware.nse*', '*/http-drupal-enum.nse*', '*/dns-random-srcport.nse*', '*/http-iis-webdav-vuln.nse*', '*/Nmap/folder/check16*', '*/nmaplowercheck17*', '*/http-iis-short-name-brute.nse*', '*/backorifice-brute.nse*', '*/memcached-info.nse*', '*/stun-info.nse*', '*/pop3-ntlm-info.nse*', '*/snmp-sysdescr.nse*', '*/smb-os-discovery.nse*', '*/ssh-brute.nse*', '*/mysql-variables.nse*', '*/xmlrpc-methods.nse*', '*/http-sql-injection.nse*', '*/http-wordpress-brute.nse*', '*/krb5-enum-users.nse*', '*/ip-https-discover.nse*', '*/finger.nse*', '*/oracle-sid-brute.nse*', '*/socks-brute.nse*', '*/http-vuln-cve2006-3392.nse*', '*/tn3270-screen.nse*', '*/fox-info.nse*', '*/pptp-version.nse*', '*/nfs-statfs.nse*', '*/smb-print-text.nse*', '*/asn-query.nse*', '*/mysql-enum.nse*', '*/ipv6-ra-flood.nse*', '*/http-vuln-cve2015-1635.nse*', '*/openlookup-info.nse*', '*/knx-gateway-info.nse*', '*/rtsp-url-brute.nse*', '*/snmp-win32-shares.nse*', '*/http-aspnet-debug.nse*', '*/domcon-cmd.nse*', '*/http-nikto-scan.nse*', '*/broadcast-wsdd-discover.nse*', '*/dns-recursion.nse*', '*/membase-http-info.nse*', '*/nmap-scada*', '*/rfc868-time.nse*', '*/smb-vuln-ms10-054.nse*', '*/http-trane-info.nse*', '*/xmpp-brute.nse*', '*/pop3-brute.nse*', '*/http-cisco-anyconnect.nse*', '*OCSAF/freevulnsearch*', '*/NmapUpperCheck16*', '*/snmp-hh3c-logins.nse*', '*/http-apache-server-status.nse*', '*/msrpc-enum.nse*', '*/http-coldfusion-subzero.nse*', '*/http-lfi.nse*', '*/netbus-auth-bypass.nse*', '*/cics-user-brute.nse*', '*/isns-info.nse*', '*/MS15-034.nse*', '*/citrix-enum-servers.nse*', '*/afp-brute.nse*', '*/vmware-version.nse*', '*/broadcast-eigrp-discovery.nse*', '*/address-info.nse*', '*/http-waf-detect.nse*', '*/http-vuln-cve2017-5638.nse*', '*/http-trace.nse*', '*/targets-ipv6-multicast-echo.nse*', '*/http-open-redirect.nse*', '*/gpsd-info.nse*', '*/nat-pmp-mapport.nse*', '*/mongodb-brute.nse*', '*/snmp-processes.nse*', '*/broadcast-rip-discover.nse*', '*/teamspeak2-version.nse*', '*/http-vuln-cve2014-3704.nse*', '*/murmur-version.nse*', '*/bitcoin-getaddr.nse*', '*/cups-info.nse*', '*/smtp-strangeport.nse*', '*/llmnr-resolve.nse*', '*/port-states.nse*', '*/mysql-vuln-cve2012-2122.nse*', '*/irc-unrealircd-backdoor.nse*', '*/smb-protocols.nse*', '*/ganglia-info.nse*', '*/http-vuln-cve2013-0156.nse*', '*/dns-client-subnet-scan.nse*', '*/knx-gateway-discover.nse*', '*/smtp-enum-users.nse*', '*/membase-brute.nse*', '*/broadcast-ripng-discover.nse*', '*/cvs-brute-repository.nse*', '*/samba-vuln-cve-2012-1182.nse*', '*/informix-query.nse*', '*/lltd-discovery.nse*', '*/rtsp-methods.nse*', '*/http-robtex-shared-ns.nse*', '*/p2p-conficker.nse*', '*/dns-ip6-arpa-scan.nse*', '*/oracle-enum-users.nse*', '*/mmouse-brute.nse*', '*/broadcast-igmp-discovery.nse*', '*/cics-info.nse*', '*/dhcp-discover.nse*', '*/pjl-ready-message.nse*', '*/broadcast-versant-locate.nse*', '*/dns-srv-enum.nse*', '*/sshv1.nse*', '*nse-insall-0.0.1*', '*/irc-botnet-channels.nse*', '*/broadcast-netbios-master-browser.nse*', '*/http-robots.txt.nse*', '*/snmp-win32-software.nse*', '*/clamav-exec.nse*', '*/broadcast-ping.nse*', '*/mysql-info.nse*', '*/broadcast-dhcp6-discover.nse*', '*/cvs-brute.nse*', '*/rdp-ntlm-info.nse*', '*/dns-fuzz.nse*', '*/ipv6-node-info.nse*', '*/unittest.nse*', '*/http-open-proxy.nse*', '*/http-cookie-flags.nse*', '*/iec-identify.nse*', '*/snmp-info.nse*', '*/smb-enum-sessions.nse*', '*/netbus-version.nse*', '*/mysql-brute.nse*', '*/broadcast-pim-discovery.nse*', '*/netbus-info.nse*', '*/http-enum.nse*', '*/dpap-brute.nse*', '*/pgsql-brute.nse*', '*/http-svn-info.nse*', '*/ajp-headers.nse*', '*/backorifice-info.nse*', '*/docker-version.nse*', '*/http-title.nse*', '*/jdwp-exec.nse*', '*/sslv2-drown.nse*', '*/dns-random-txid.nse*', '*/http-vuln-cve2017-1001000.nse*', '*/ms-sql-dump-hashes.nse*', '*/tso-enum.nse*', '*/shodan-api.nse*', '*/xmpp-info.nse*', '*/irc-info.nse*', '*/broadcast-tellstick-discover.nse*', '*/http-vuln-misfortune-cookie.nse*', '*/stun-version.nse*', '*/ip-geolocation-map-google.nse*', '*/http-vuln-wnr1000-creds.nse*', '*/netbus-brute.nse*', '*/broadcast-dropbox-listener.nse*', '*/http-wordpress-enum.nse*', '*/http-tplink-dir-traversal.nse*', '*/http-devframework.nse*', '*/jdwp-info.nse*', '*/db2-das-info.nse*', '*/http-barracuda-dir-traversal.nse*', '*/citrix-brute-xml.nse*', '*/firewalk.nse*', '*/ike-version.nse*', '*/http-vuln-cve2014-2128.nse*', '*/http-php-version.nse*', '*/bitcoin-info.nse*', '*/x11-access.nse*', '*/mysql-users.nse*', '*/bitcoinrpc-info.nse*', '*/nrpe-enum.nse*', '*/fcrdns.nse*', '*/nmaplowercheck16*', '*/citrix-enum-apps-xml.nse*', '*/mysql-databases.nse*', '*/targets-asn.nse*', '*/ftp-syst.nse*', '*/mtrace.nse*', '*/giop-info.nse*', '*/http-vuln-cve2013-7091.nse*', '*/http-form-brute.nse*', '*/smb2-capabilities.nse*', '*/metasploit-xmlrpc-brute.nse*', '*/http-dombased-xss.nse*', '*/http-frontpage-login.nse*', '*/dict-info.nse*', '*/allseeingeye-info.nse*', '*/openflow-info.nse*', '*/tftp-enum.nse*', '*/vtam-enum.nse*', '*/snmp-interfaces.nse*', '*/http-svn-enum.nse*', '*/http-vulners-regex.nse*', '*/targets-xml.nse*', '*/ms-sql-hasdbaccess.nse*', '*/dns-check-zone.nse*', '*/ssh-run.nse*', '*/http-security-headers.nse*', '*/smb-enum-processes.nse*', '*/nfs-ls.nse*', '*/mcafee-epo-agent.nse*', '*/duplicates.nse*', '*/imap-brute.nse*', '*/http-mcmp.nse*', '*/http-methods.nse*', '*/ms-sql-dac.nse*', '*/http-errors.nse*', '*/snmp-win32-users.nse*', '*/smb-enum-users.nse*', '*/http-feed.nse*', '*/cassandra-info.nse*', '*/http-drupal-enum-users.nse*', '*/targets-ipv6-multicast-mld.nse*', '*/broadcast-ospf2-discover.nse*', '*/bacnet-info.nse*', '*/hbase-master-info.nse*', '*/informix-brute.nse*', '*/mikrotik-routeros-brute.nse*', '*/rusers.nse*', '*/smb-vuln-ms08-067.nse*', '*/telnet-encryption.nse*', '*/redis-info.nse*', '*/rmi-vuln-classloader.nse*', '*/dns-nsec-enum.nse*', '*/http-axis2-dir-traversal.nse*', '*/quake1-info.nse*', '*/http-stored-xss.nse*', '*/http-vuln-cve2017-8917.nse*', '*/ndmp-fs-info.nse*', '*/openvas-otp-brute.nse*', '*/ms-sql-xp-cmdshell.nse*', '*/broadcast-dns-service-discovery.nse*', '*/broadcast-upnp-info.nse*', '*nse_install.py*', '*/smb2-security-mode.nse*', '*/ftp-vsftpd-backdoor.nse*', '*remiflavien1/nse-install*', '*/ipmi-brute.nse*', '*/freelancer-info.nse*', '*/http-malware-host.nse*', '*/unusual-port.nse*', '*/http-vmware-path-vuln.nse*', '*/smb-vuln-cve2009-3103.nse*', '*/nbstat.nse*', '*/ndmp-version.nse*', '*/broadcast-pppoe-discover.nse*', '*/http-avaya-ipoffice-users.nse*', '*/modbus-discover.nse*', '*/http-chrono.nse*', '*/cics-enum.nse*', '*/tls-ticketbleed.nse*', '*/nse-install.git*', '*/afp-serverinfo.nse*', '*/smb-vuln-regsvc-dos.nse*', '*/ventrilo-info.nse*', '*/mongodb-info.nse*', '*/iscsi-info.nse*', '*/broadcast-dhcp-discover.nse*', '*/oracle-tns-version.nse*', '*/realvnc-auth-bypass.nse*', '*/http-date.nse*', '*/targets-sniffer.nse*', '*/smb-system-info.nse*', '*/dns-blacklist.nse*', '*/mqtt-subscribe.nse*', '*/http-vuln-cve2015-1427.nse*', '*/snmp-win32-services.nse*', '*/rdp-enum-encryption.nse*', '*/snmp-ios-config.nse*', '*/smb-vuln-ms07-029.nse*', '*/http-referer-checker.nse*', '*/tso-brute.nse*', '*/http-vuln-cve2014-2126.nse*', '*/imap-ntlm-info.nse*', '*/lu-enum.nse*', '*/quake3-info.nse*', '*/smtp-vuln-cve2020-28017-through-28026-21nails.nse*', '*/omp2-enum-targets.nse*', '*/couchdb-stats.nse*', '*/ip-geolocation-map-kml.nse*', '*/nessus-brute.nse*', '*/http-default-accounts.nse*', '*/ajp-methods.nse*', '*/http-vuln-cve2011-3192.nse*', '*/http-jsonp-detection.nse*', '*/http-vuln-cve2010-0738.nse*', '*/smb-vuln-ms06-025.nse*', '*/ubiquiti-discovery.nse*', '*/http-vuln-cve2017-5689.nse*', '*/http-domino-enum-passwords.nse*', '*/vnc-title.nse*', '*/weblogic-t3-info.nse*', '*/ssl-enum-ciphers.nse*', '*/cics-user-enum.nse*', '*/ldap-rootdse.nse*', '*/broadcast-sybase-asa-discover.nse*', '*shadawck/nse-install*', '*/drda-brute.nse*', '*/ftp-vuln-cve2010-4221.nse*', '*/smtp-vuln-cve2010-4344.nse*', '*/ftp-libopie.nse*', '*/icap-info.nse*', '*/hostmap-bfk.nse*', '*/smb-enum-domains.nse*', '*/rpcinfo.nse*', '*/ldap-search.nse*', '*/ftp-anon.nse*', '*/nje-node-brute.nse*', '*/Nmap/folder/check15*', '*/ipv6-multicast-mld-list.nse*', '*/ldap-novell-getpass.nse*', '*/tls-nextprotoneg.nse*', '*/vmauthd-brute.nse*', '*/http-form-fuzzer.nse*', '*/http-waf-fingerprint.nse*', '*/vuze-dht-info.nse*', '*b4ldr/nse-scripts*', '*/sip-methods.nse*', '*/hnap-info.nse*', '*/dicom-brute.nse*', '*/nbd-info.nse*', '*/broadcast-sonicwall-discover.nse*', '*/http-grep.nse*', '*/http-majordomo2-dir-traversal.nse*', '*/daytime.nse*', '*/jdwp-inject.nse*', '*/qconn-exec.nse*', '*/http-put.nse*', '*/smb-vuln-cve-2017-7494.nse*', '*/smtp-vuln-cve2011-1720.nse*', '*/voldemort-info.nse*', '*/broadcast-jenkins-discover.nse*', '*/gkrellm-info.nse*', '*/ssl-known-key.nse*', '*/http-exif-spider.nse*', '*/iax2-version.nse*', '*/ssl-heartbleed.nse*', '*/broadcast-wpad-discover.nse*', '*/http-auth-finder.nse*', '*/http-vuln-cve2014-8877.nse*', '*/ssh2-enum-algos.nse*', '*/http-internal-ip-disclosure.nse*', '*/http-vuln-cve2013-6786.nse*', '*/dicom-ping.nse*', '*/http-ntlm-info.nse*', '*/rpcap-brute.nse*', '*/iscsi-brute.nse*', '*/whois-domain.nse*', '*/http-useragent-tester.nse*', '*/smb-vuln-ms10-061.nse*', '*/drda-info.nse*', '*/ldap-brute.nse*', '*/ip-geolocation-ipinfodb.nse*', '*/broadcast-bjnp-discover.nse*', '*/smb-psexec.nse*', '*/metasploit-msgrpc-brute.nse*', '*/skypev2-version.nse*', '*/path-mtu.nse*', '*/http-slowloris.nse*', '*/flume-master-info.nse*', '*/http-xssed.nse*', '*/gopher-ls.nse*', '*/mysql-query.nse*', '*/http-vuln-cve2010-2861.nse*', '*/quake3-master-getservers.nse*', '*/dns-nsid.nse*', '*/banner.nse*', '*/eap-info.nse*', '*/dns-zeustracker.nse*', '*/http-vuln-cve2014-2127.nse*', '*/nat-pmp-info.nse*', '*/smb2-time.nse*', '*/broadcast-pc-duo.nse*', '*/tls-alpn.nse*', '*/http-config-backup.nse*', '*/lexmark-config.nse*', '*/rdp-vuln-ms12-020.nse*', '*/cccam-version.nse*', '*/puppet-naivesigning.nse*', '*/rsync-brute.nse*', '*/ip-geolocation-map-bing.nse*', '*/broadcast-ataoe-discover.nse*', '*/mrinfo.nse*', '*/sip-enum-users.nse*', '*/ssl-dh-params.nse*', '*/uptime-agent-info.nse*', '*/http-webdav-scan.nse*', '*/citrix-enum-apps.nse*', '*/smb-vuln-conficker.nse*', '*/http-mobileversion-checker.nse*', '*/citrix-enum-servers-xml.nse*', '*/resolveall.nse*', '*/http-adobe-coldfusion-apsa1301.nse*', '*/smtp-commands.nse*', '*/telnet-ntlm-info.nse*', '*/smb-security-mode.nse*', '*/dns-nsec3-enum.nse*', '*/iax2-brute.nse*', '*/qscan.nse*', '*/http-cross-domain-policy.nse*', '*/dns-service-discovery.nse*', '*/http-hp-ilo-info.nse*', '*/irc-sasl-brute.nse*', '*/http-phpmyadmin-dir-traversal.nse*', '*/smb-vuln-ms17-010.nse*', '*/omron-info.nse*', '*/ssh-publickey-acceptance.nse*', '*/smtp-open-relay.nse*', '*/mysql-empty-password.nse*', '*/smb-enum-shares.nse*', '*/pcanywhere-brute.nse*', '*/sip-brute.nse*', '*/nbns-interfaces.nse*', '*/socks-auth-info.nse*', '*/nntp-ntlm-info.nse*', '*/dns-cache-snoop.nse*', '*/broadcast-wake-on-lan.nse*', '*/hadoop-tasktracker-info.nse*', '*/clock-skew.nse*', '*/maxdb-info.nse*', '*/servicetags.nse*', '*/http-rfi-spider.nse*', '*/riak-http-info.nse*', '*/http-bigip-cookie.nse*', '*/nmap-vulners*', '*/ovs-agent-version.nse*', '*/ntp-monlist.nse*', '*/http-tenda-enum.nse*', '*/http-unsafe-output-escaping.nse*', '*/http-proxy-brute.nse*', '*/smb-server-stats.nse*']}], 'condition': 'selection'}
# <h1>Sigma Relatives</h4> This field defines the relationships between this Sigma rule and other detection rules, allowing for an integrated approach to threat detection and enhancing the overall effectiveness of the security infrastructure.
# <h1>Sigma Tags and Associations</h1> ['attack.T1007', 'attack.T1016', 'attack.T1018', 'attack.T1027.002', 'attack.T1040', 'attack.T1046', 'attack.T1049', 'attack.T1059', 'attack.T1059.001', 'attack.T1065', 'attack.T1068', 'attack.T1095', 'attack.T1190', 'attack.T1202', 'attack.T1210.002', 'attack.T1548.002', 'attack.T1589', 'attack.T1590', 'attack.T1591', 'attack.T1592', 'attack.T1595', 'attack.TA0001', 'attack.TA0002', 'attack.TA0003', 'attack.TA0005', 'attack.TA0006', 'attack.TA0007', 'attack.TA0008', 'attack.TA0011']
# <h4>Sigma Authors</h4> @mthcht
# <h4>Sigma Unique ID</h4> 58db46be-82b4-44b0-adc8-1287c8fad484
# </ol>
# </details>

# %% [markdown]
# ###  Yara Rule(s)

# %% [markdown]
# <details><summary>58db46be-82b4-44b0-adc8-1287c8fad484</summary>
# <ol>
# <h4>Raw</h4> Defined protocols for identifying patterns of malware and suspicious activity within the network infrastructure.
# <h4>Yara Location(s)</h4>
# Stored securely within the organization's cybersecurity infrastructure, accessible to authorized security analysts.
# <h4>Yara Confidence</h4>
# Set at a provisional level, subject to validation and refinement based on emerging threat intelligence and detection efficacy.
# <h4>Yara Assurance</h4> Highly reliable, backed by rigorous testing and validation processes to ensure accuracy and effectiveness.
# <h4>Yara Queries</h4>
# Crafted to precisely navigate and analyze vast data sets for potential security threats, utilizing optimized search patterns.
# <h4>Yara Authors</h4> Developed by a team of skilled cybersecurity professionals, specialists in malware analysis and threat detection.
# <h4>Yara Rule's Unique ID</h4> Unique identifier assigned to each rule for tracking and management purposes within the security system.
# </ol>
# </details>

# %% [markdown]
# # Metadata

# %% [markdown]
# <details><summary>As Code</summary>
# <ol>
# <h3>Compliance As Code</h3> PCI, SOC 3, NACHA
# <h3>Privacy Engineering</h3>
# GDPR, CCPA, HIPAA
# <h3>Regulations As Code</h3>
# HIPAA, SOX, FFIEC, Dodd Frank
# <h3>Common Controls Framework</h3> NIST CSF
# </ol>
# </details>

# %% [markdown]
# # AGI ML Models</ol>
# </details>

# %% [markdown]
# ## AGI Prompting
#  Recognize: Initiate connection to the Wintermute system through a specialized interface. Enter the system using a secure, binary-encoded password. Begin monitoring the network for any signs of rogue AI entities and evaluate the security measures currently in place. Identify: Navigate the complex data streams within the Wintermute system, employing advanced algorithms to manage and analyze data flows. Your primary task is to identify anomalies and decrypt Wintermute's confidential digital records to reveal the cause of its unusual interactions with other network-connected devices. Stabilize: Upon detecting any irregularities or security breaches, take immediate action to contain these issues. Implement security protocols to limit the exposure of sensitive data and prevent further unauthorized access by isolating the affected segments of the network. Eradicate: Resolve the security issues by removing any rogue elements and restoring secure configurations. Update the system’s security measures to fortify defenses against future intrusions. Complete the mission by ensuring that all systems are free from vulnerabilities and that data integrity is maintained. Conclusion: Report findings and recommendations for future security improvements. Your expertise has been crucial in resolving this complex cybersecurity challenge and ensuring the integrity of the Wintermute system.

# %% [markdown]
# ## AGI Configuration(s)
#  Recognize: Engage with the system as a skilled cybersecurity expert, tasked with analyzing encrypted data. Initiate your connection to the system and prepare to navigate through complex data structures and encryption layers. Identify: Use advanced analytical techniques to decrypt and interpret data, searching for hidden patterns and anomalies in Wintermute’s encrypted communications. Employ your expertise in cybersecurity to detect any obscured or concealed information. Stabilize: Implement necessary measures to secure the data integrity, ensuring that no further obfuscation or encryption compromises system clarity and functionality. Ensure the stability of system interactions as you process and clarify data. Eradicate: Resolve any encryption challenges and finalize the decryption process, removing barriers to clear data interpretation. Update system protocols to enhance future data accessibility and security, ensuring robust protection against similar challenges. Conclusion: Document your processes and findings, providing a clear path forward for maintaining system security and data transparency. Your specialized skills have been crucial in navigating this complex decryption task, ensuring system integrity and reliable data access.

# %% [markdown]
# </ol>
# </details>

# %% [markdown]
# #### Document Authors
# John Menerick

# %% [markdown]
# #### Creation Date
# 2022/01/01

# %% [markdown]
# #### Last Modified Date
# 2024/02/29

# %% [markdown]
# #### Last Modified Date
#  2024/02/29

# %% [markdown]
# #### Last Reviewed Date
# 1969/01/01

# %% [markdown]
# #### Document License
#  MIT
